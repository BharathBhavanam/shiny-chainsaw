# %% [markdown]
# 3.operators

# %%
a,b=10, 3
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# Arthimetic Example

# %%
price=100
quantity=5
tax=0.12
total=price*quantity*(1+tax)
print(total)
# Out:
# 560.0

# %%
print(10>5)#false
print(10 == 5)#false
print(10!=5)#true
# Out:
# True
# False
# True

# %% [markdown]
# Logical operation

# %%
x, y = True,False
print(x and y)# prints both
print(x or y)#prints true's
print(not x)#prints other than mentioned one
# Out:
# False
# True
# False

# %% [markdown]
# lists

# %%
names=["bob","jam"]
len(names)
print(names[0])
# Out:
# bob

# %%
age = 22
has_id = True
print(age >= 18 and has_id)
# Out:
# True

# %%
income = 50000
credit_score = 720
eligible = income > 30000 and credit_score >= 720
print(eligible)
# Out:
# True

# %%
names.append("ram")

# %%
print(names)
# Out:
# ['bob', 'jam', 'ram']

# %%
print(names[:3])
# Out:
# ['bob', 'jam', 'ram']

# %%
nums=[10,20,30,40,50]
print(nums[-3:])
print(nums[::-3])
# Out:
# [30, 40, 50]
# [50, 20]

# %% [markdown]
# loop

# %%
marks= int(input("enter the marks:"))
if marks>=90:
    print("A")
elif marks>=80:
    print("B")
elif marks>=70:
    print("C")
else:
    print("NOT SATISFYIED")
# Out:
# enter the marks: 89
# B

# %% [markdown]
# list comprehenisons

# %%
numbers = [1,2,3,4,5]
squares = []

for x in numbers:
    squares.append(x)

# %%
words = ["python","machine learning","data science"]
upper = [w.upper() for w in words]
print(upper)
# Out:
# ['PYTHON', 'MACHINE LEARNING', 'DATA SCIENCE']

# %% [markdown]
# dictionary

# %%
student = {"name":"alice","age":24, "marks":90}
print(student["age"])
# Out:
# 24

# %% [markdown]
# #add #update #delete

# %%
student = {'name':'Alice', 'age':24}
student["city"] = "surat"
print(student)
# Out:
# {'name': 'Alice', 'age': 24, 'city': 'surat'}

# %%
del student["age"]
print(student)
# Out:
# {'name': 'Alice', 'city': 'surat'}

# %%
marks={'Telugu':89, 'English':78, 'Math':90}
for subject, score in marks.items():
    print(subject,"->",score)
# Out:
# Telugu -> 89
# English -> 78
# Math -> 90

# %% [markdown]
# tuples

# %%
cord=(12,43,34)
print(cord[0])
# Out:
# 12

# %% [markdown]
# sets

# %%
nums={1,1,2,2,32,3,4,3,5,7,5,1,2}
print(nums)
# Out:
# {32, 1, 2, 3, 4, 5, 7}

# %%
item = ['a','b','a','c','d']
unique = set(item)
print(unique)
# Out:
# {'b', 'c', 'd', 'a'}

# %%
a = {3,4,2,5,6}
b = {1,2,3,4,5}

# %%
#union
print(a|b)#or operator
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#intersection
print(a&b)#and operator
# Out:
# {2, 3, 4, 5}

# %% [markdown]
# file handling

# %%
#creating a file
with open("sample.txt","w") as a:
    a.write("Hello")

# %%
#reading the file
with open("sample.txt","r") as a:
    msg = a.read()
print(msg)
# Out:
# Hello

# %% [markdown]
# Exception Handling

# %%
try:
    result = 10/0
except ZeroDivisionError:
    print("cannot divide by 0")
# Out:
# cannot divide by 0

# %%
try:
    n = int("abc")
except ValueError:
    print("not a valid number")
# Out:
# not a valid number

# %% [markdown]
# Modules

# %%
#math module
import math
print(math.sqrt(2225))
# Out:
# 47.16990566028302

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.factorial(3))
# Out:
# 6

# %%
#random module
import random

# %%
print(random.randint(1,100))
# Out:
# 97

# %%
print(random.choice(['BOB','ROHIT','SAI','MAM']))
# Out:
# BOB
